# %%
import numpy as np

# %%
data = [10, 10, 20, 30, 30, 30, 40, 100, 48]

# %%
print("Mean:", np.mean(data))
# Out:
# Mean: 35.333333333333336

# %%
print("Median:", np.median(data))
# Out:
# Median: 30.0

# %%
import statistics

# %%
statistics.mode(data)
# Out:
# 30

# %%
np.var(data)
# Out:
# np.float64(663.1111111111109)

# %%
np.var(data[0:4], ddof=1)
# Out:
# np.float64(91.66666666666667)

# %%
np.random.seed(88)

# %%
pop = np.random.normal(loc=5,scale=10,size=1000000)
