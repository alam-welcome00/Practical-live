# %%
# 1. Connection string
# Copy the connection details for your database.
# Details:
# Shared Pooler
# If your database password contains special characters, you will need to percent-encode them in the connection string.
# Forgot your database password?
# host:aws-0-ap-southeast-1.pooler.supabase.com
# port:5432
# database:postgres
# user:postgres.bewwhrggyrhsiileumrb
# Code:
# File: Code
# ```
# postgresql://postgres.bewwhrggyrhsiileumrb:[YOUR-PASSWORD]@aws-0-ap-southeast-1.pooler.supabase.com:5432/postgres
# ```

# 2. Install Agent Skills (Optional)
# Agent Skills give AI coding tools ready-made instructions, scripts, and resources for working with Supabase more accurately and efficiently.
# Details:
# npx skills add supabase/agent-skills
# Code:
# File: Code
# ```
# npx skills add supabase/agent-skills
# ```

# %% [markdown]
# 1. Install dependencies
# Run this command to install the required dependencies.
# Code:
# File: Code
# ```
# pip install python-dotenv psycopg2
# ```
#
# 2. Add files
# Add the following files to your project.
# Details:
# If your database password contains special characters, you will need to percent-encode them in the connection string.
# host:aws-0-ap-southeast-1.pooler.supabase.com
# port:5432
# database:postgres
# user:postgres.bewwhrggyrhsiileumrb
# Code:
# File: main.py
# ```
# 1import psycopg2
# 2from dotenv import load_dotenv
# 3import os
# 4
# 5# Load environment variables from .env
# 6load_dotenv()
# 7
# 8# Fetch variables
# 9DATABASE_URL = os.getenv("DATABASE_URL")
# 10
# 11# Connect to the database
# 12connection = psycopg2.connect(DATABASE_URL)
# ```
#
# File: .env
# ```
# DATABASE_URL=postgresql://postgres.bewwhrggyrhsiileumrb:[YOUR-PASSWORD]@aws-0-ap-southeast-1.pooler.supabase.com:5432/postgres
# ```
#
# 3. Install Agent Skills (Optional)
# Agent Skills give AI coding tools ready-made instructions, scripts, and resources for working with Supabase more accurately and efficiently.
# Details:
# npx skills add supabase/agent-skills
# Code:
# File: Code
# ```
# npx skills add supabase/agent-skills
# ```

# %%
import os

print(os.getcwd())
print(os.path.exists(".env"))
# Out:
# d:\Data Science\Practical live\level_2\lecture\15-03-2026\prac
# True

# %%
import psycopg2
from dotenv import load_dotenv
import os

# Load environment variables from .env
load_dotenv()

# Fetch variables
DATABASE_URL = os.getenv("DATABASE_URL")

# Connect to the database
connection = psycopg2.connect(DATABASE_URL)

# %%
cursor = connection.cursor()

# %%
cursor.execute("SELECT * FROM sut_table;")
result = cursor.fetchall()
print(result)
# Out:
# [(1, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Aarav', 15, '10'), (2, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Priya', 14, '9'), (3, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Rahul', 16, '11'), (4, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Sneha', 15, '10'), (5, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Arjun', 13, '8'), (6, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Neha', 17, '12'), (7, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Vikram', 14, '9'), (8, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Ananya', 16, '11'), (9, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Rohan', 15, '10'), (10, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819,
# ...

# %%
for r in result:
    print(r)
# Out:
# (1, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Aarav', 15, '10')
# (2, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Priya', 14, '9')
# (3, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Rahul', 16, '11')
# (4, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Sneha', 15, '10')
# (5, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Arjun', 13, '8')
# (6, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Neha', 17, '12')
# (7, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Vikram', 14, '9')
# (8, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Ananya', 16, '11')
# (9, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Rohan', 15, '10')
# ...

# %%
student_val = ("Sameer Alam", 20,9)
cursor.execute('''
    INSERT INTO sut_table (name, age,class) VALUES (%s,%s,%s)
''',student_val)

# %%
cursor.execute('''
    SELECT * FROM sut_table

''')
result = cursor.fetchall()

for r in result:
    print(r)
# Out:
# (1, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Aarav', 15, '10')
# (2, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Priya', 14, '9')
# (3, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Rahul', 16, '11')
# (4, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Sneha', 15, '10')
# (5, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Arjun', 13, '8')
# (6, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Neha', 17, '12')
# (7, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Vikram', 14, '9')
# (8, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Ananya', 16, '11')
# (9, datetime.datetime(2026, 7, 24, 2, 34, 29, 110819, tzinfo=datetime.timezone.utc), 'Rohan', 15, '10')
# ...

# %%
connection.commit()
