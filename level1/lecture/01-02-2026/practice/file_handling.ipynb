# %%
import os

# %%
a= os.getcwd()
print(a)
# Out:
# d:\Data Science\Practical live\level1\lecture\01-02-2026

# %%
os.chdir("01-02-2026")

# %%
a = "level1\\lecture\\01-02-2026\\temp\\temp_1.txt"
folder_name = "temp"
file_name = "temp_1.txt"
full_path = os.path.join(os.getcwd(),folder_name,file_name)
print(full_path)
with open(full_path,"r") as f:
    print(f.tell()) # location of the cursuer
    content = f.read()
    print(f.tell())
    print(content)
print(full_path)
# Out:
# d:\Data Science\Practical live\level1\lecture\01-02-2026\temp\temp_1.txt
# 0
# 586
# Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# It has survived not only five centuries, but also the leap into electronic typesetting,
# remaining essentially unchanged. It was popularised in the 1960s
# with the release of Letraset sheets containing Lorem Ipsum passages,
# and more recently with desktop publishing software like Aldus PageMaker
# including versions of Lorem Ipsum.
# d:\Data Science\Practical live\level1\lecture\01-02-2026\temp\temp_1.txt

# %%
a = os.getcwd()
print(a)
# Out:
# d:\Data Science\Practical live\level1\lecture\01-02-2026

# %%
with open("temp/temp_1_copy.txt","w") as f:
    print(f.tell())
    f.write("Sameer!! welcome in the course")
    print(f.tell())
# Out:
# 0
# 30

# %%
with open("temp/temp_1_copy.txt","r") as f:
    print(f.tell())
    # f.write("Sameer!! welcome in the course")
    all_cont = f.read()
    print(f.tell())
    print(all_cont)
# Out:
# 0
# 30
# Sameer!! welcome in the course

# %%
with open("temp/temp_1_copy.txt","a") as f:
    print(f.tell())
    f.write("this is best for your, you will learn very much things here")
    # all_cont = f.read()
    print(f.tell())
    print(all_cont)
# Out:
# 30
# 88
# Sameer!! welcome in the course

# %%
with open("temp/temp_1_copy.txt","a") as f:
    print(f.tell())
    f.write("--\ntoday you will complete this python intermediate level \nand from tomorrow you have to learn oops")
    # all_cont = f.read()
    print(f.tell())
    print(all_cont)
# Out:
# 88
# 189
# Sameer!! welcome in the course

# %%
print(os.getcwd())
# Out:
# d:\Data Science\Practical live\level1\lecture\01-02-2026

# %%
with open("temp/temp_1_copy.txt","r+") as f:
    print(f.tell())
    # f.write("Fuck you motherfuckerrr")
    cont = f.read()
    print(cont)
    print(f.tell())
# Out:
# 0
# Fuck you motherfuckerrr coursethis is best for your, you willlearn very much things here--
# today you will complete this python intermediate level
# and from tomorrow you have to learn oops
# 189

# %%
with open("temp/temp_1_copy_2.txt", "a+") as f:
    print(f.tell()) # tells the current location of pointer
    all_contents = f.read()
    f.write("need to fuck you annuuu****")
    print(f.tell()) # tells the current location of pointer
    print(all_contents)
# Out:
# 202
# 229

# %%
5/3
# Out:
# 1.6666666666666667

# %%
with open("temp//sam.txt","w+") as f:
    firs_ind = f.tell()
    f.write("what you want annu lauda legi mera "
    "\nkuttiya sali rand jada bolegi to muh mai de duga"
    "\nchut ki dhakka sali")

    last_ind = f.tell()

    mid_ind = (last_ind//2)+1
    print(mid_ind)

    f.seek(mid_ind)
    f.write("muh me lele")
    print(f.tell())
# Out:
# 54
# 65
