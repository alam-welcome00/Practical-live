# %% [markdown]
# ## Propertie of something is called method
# stinge have some properties like
# stip
# lstip
# rstrip
#
#
# it remove extra space from left and right

# %%
s = "   Sameer Alam  "
s.strip

# %% [markdown]
# # Operator

# %% [markdown]
# #### Relational Operator

# %%
a = 10
b = 12

print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# True
# False
# False
# True

# %%
age_thershold = 18
person_age = 16

print(person_age>=age_thershold)
# Out:
# False

# %% [markdown]
# #### Assigment Operators

# %%
a = 10
print(a)
# Out:
# 10

# %%
a+=1
print(a)
# Out:
# 11

# %%
a-=1
print(a)
# Out:
# 10

# %%
a*=2
print(a)
# Out:
# 20

# %%
a//=3
print(a)
# Out:
# 6

# %% [markdown]
# #### Logical Operator

# %%
bool_a =True
bool_b =False

# %%
bool_a and bool_b
# Out:
# False

# %%
bool_a or bool_b
# Out:
# True

# %%
not bool_b
# Out:
# True

# %% [markdown]
# #### Bitwise Operator

# %%
a = 1
b = 3

# %%
print(a&b)
# Out:
# 1

# %%
print(a | b)
# Out:
# 3

# %%
print(~a)
# Out:
# -2

# %%
print(a^b)
# Out:
# 2

# %%
a = 30
bin(a)
# Out:
# '0b11110'
