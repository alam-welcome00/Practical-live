# %%
class Course:
    def __init__(self):
        self.data= {}

    def add_student(self):
        cust_id = input("Enter customer ID (first four letter of your name and four number): ")
        name = input("Enter your name: ")
        age = int(input("Enter your age: "))
        course = input("Enter your course: ")
        email = input("Enter your email: ")

        self.data[cust_id]={
            "name": name,
            "age": age,
            "course": course.lower()
        }

    def display_stud(self):
        for cust_id, details in self.data.items():
            print(f"\ncust_id: {cust_id}")
            for key, value in details.items():
                print(f"{key.capitalize()}: {value}")

ultimate_data_science = Course()

ultimate_data_science.add_student()
ultimate_data_science.add_student()
ultimate_data_science.add_student()
ultimate_data_science.add_student()

ultimate_data_science.display_stud()

# %%
ultimate_data_science.add_student()
ultimate_data_science.add_student()
ultimate_data_science.add_student()
ultimate_data_science.add_student()

# %%
ultimate_data_science.display_stud()
# Out:
# cust_id: same1234
# Name: sameera
# Age: 21
# Course: data analytics
#
# cust_id: alam12344
# Name: alam
# Age: 44
# Course: ml and ai
#
# cust_id: nawaz
# Name: naw
# Age: 33
# Course: dsa
#
# cust_id: me1233
# Name: meena
# Age: 44
# Course: da
