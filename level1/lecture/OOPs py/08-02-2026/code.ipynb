# %%
import string
import secrets
import time

class Customer:
    def __init__(self):
        self.cust_data = {}

    def add_user(self,type_of_user,type_of_acc):
        cust_name = input("Enter your valid name: ")
        cust_age = int(input("Enter your age as per govnt ID: "))
        number = int(input("Enter your phone number: "))
        cust_id_first = "".join(cust_name.split())[:4].upper()
        pool = string.ascii_uppercase + string.digits
        cust_id_second = "".join(secrets.choice(pool) for _ in range(10))
        cust_id = cust_id_first + cust_id_second
        creation_time = time.time()

        self.cust_data = {cust_id:{"cust_name":cust_name,
                                     "cust_age":cust_age,
                                     "cust_contact":number,
                                     "create_At":creation_time}}
    def register_cust(self):
        for a,b in self.cust_data.item():
            print(f"{a}:{b}")

# %%
print("code is running")
c1 = Customer()
# Out:
# code is running

# %%
c1.add_user("general user","saving acc")

# %%
c1.register_cust()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 c1.register_cust()
#
# Cell In[1], line 24, in Customer.register_cust(self)
#      23     def register_cust(self):
# ---> 24         for a,b in self.cust_data.item():
#      25             print(f"{a}:{b}")
#
# AttributeError: 'dict' object has no attribute 'item'
