# %% [markdown]
# # Non premitive data type

# %% [markdown]
# #### List

# %%
l = ["Hello", "Hey", "Python", 10, False]

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10, False]

# %%
l[0]
# Out:
# 'Hello'

# %%
l.append("Data Science Course")

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10, False, 'Data Science Course']

# %%
l[-1]
# Out:
# 'Data Science Course'

# %%
l.remove(10)

# %%
l.remove(False)

# %%
l.sort()

# %%
l
# Out:
# ['Data Science Course', 'Hello', 'Hey', 'Python']

# %%
l.insert(3,"You")

# %%
l
# Out:
# ['Data Science Course', 'Hello', 'Hey', 'You', 'Python']

# %%
l[len(l)-1]
# Out:
# 'Python'

# %%
l[1:3]
# Out:
# ['Hello', 'Hey']

# %%
l.pop()
# Out:
# 'Python'

# %% [markdown]
# ### Dictionary

# %%
# {key : value}

register = {
    "Rohit" : ["12-12-1980", 123456789, "abcdefgh"],
    "Rohith" : ["12-12-1980", 123456789, "abcd"],
    "monal" : False
}

# %%
print(register)
# Out:
# {'Rohit': ['12-12-1980', 123456789, 'abcdefgh'], 'Rohith': ['12-12-1980', 123456789, 'abcd'], 'monal': False}

# %%
goverment_sys = {
    101 : ["Monal"],
    102 : ["Amit"],
    103 : ["Dhaval"],
    104 : ["Surya"]
}

# %%
goverment_sys[101]
# Out:
# ['Monal']

# %%
goverment_sys.get(101, "Value is not present")
# Out:
# ['Monal']

# %%
goverment_sys.get(1001, "Value is not present")
# Out:
# 'Value is not present'

# %%
goverment_sys.keys()
print(list(goverment_sys.keys()))
# Out:
# [101, 102, 103, 104]

# %%
register_v2 = {
    101 : {
        "Name" : "Monal",
        "DOB" : (10, "feb", 1920),
        "Phone.no" : "+91-1111111111"
    },
    102 : {
        "Name" : "Ashish",
        "DOB" : (10, "feb", 1990),
        "Phone.no" : "+91-1111111111"
    }
}

# int, float, string, boolean
# list, dict, tuple

# %%
register_v2[102]["Phone.no"]
# Out:
# '+91-1111111111'

# %%
register_v2[101][["DOB"],["Name"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 register_v2[101][["DOB"],["Name"]]
#
# TypeError: unhashable type: 'list'
